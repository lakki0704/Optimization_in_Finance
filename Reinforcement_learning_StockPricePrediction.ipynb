# %%
import keras
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from keras.optimizers import Adam
import math
import numpy as np
import random
from collections import deque

# %%
class Agent:
    def __init__(self, state_size, is_eval=False, model_name=""):
        self.state_size = state_size # normalized previous days
        self.action_size = 3 # sit, buy, sell
        self.memory = deque(maxlen=1000)
        self.inventory = []
        self.model_name = model_name
        self.is_eval = is_eval
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.model = load_model(model_name) if is_eval else self._model()
    def _model(self):
        model = Sequential()
        model.add(Dense(units=64, input_dim=self.state_size, activation="relu"))
        model.add(Dense(units=32, activation="relu"))
        model.add(Dense(units=8, activation="relu"))
        model.add(Dense(self.action_size, activation="linear"))
        model.compile(loss="mse", optimizer=Adam(lr=0.001))
        return model
    def act(self, state):
        if not self.is_eval and random.random()<= self.epsilon:
            return random.randrange(self.action_size)
        options = self.model.predict(state)
        return np.argmax(options[0])
    def expReplay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size + 1, l):
            mini_batch.append(self.memory[i])
        for state, action, reward, next_state, done in mini_batch:
            target = reward
            if not done:
                target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
def formatPrice(n):
    return("-Rs." if n<0 else "Rs.")+"{0:.2f}".format(abs(n))
def getStockDataVec(key):
    vec = []
    lines = open(r"C:\Users\laksh\Downloads\hdfc.csv","r").read().splitlines()
    for line in lines[1:]:
        #print(line)
        #print(float(line.split(",")[4]))
        vec.append(float(line.split(",")[4]))
        #print(vec)
    return vec 
def sigmoid(x):
    return 1/(1+math.exp(-x))
def getState(data, t, n):
    d = t - n + 1
    block = data[d:t + 1] if d >= 0 else -d * [data[0]] + data[0:t + 1] # pad with t0
    res = []
    for i in range(n - 1):
        res.append(sigmoid(block[i + 1] - block[i]))
    return np.array([res])

# %%
import sys
stock_name = input("Enter stock_name: ")
window_size = input("Window size : ")
episode_count = input("Episode count: ")
stock_name = str(stock_name)
window_size = int(window_size)
episode_count = int(episode_count)
agent = Agent(window_size)
data = getStockDataVec(stock_name)
l = len(data) - 1
batch_size = 32
for e in range(episode_count + 1):
    print("Episode " + str(e) + "/" + str(episode_count))
    state = getState(data, 0, window_size + 1)
    total_profit = 0
    agent.inventory = []
    for t in range(l):
        action = agent.act(state)
        # sit
        next_state = getState(data, t + 1, window_size + 1)
        reward = 0
        if action == 1: # buy
            agent.inventory.append(data[t])
            print("Buy: " + formatPrice(data[t]))
        elif action == 2 and len(agent.inventory) > 0: # sell
            bought_price = window_size_price = agent.inventory.pop(0)
            reward = max(data[t] - bought_price, 0)
            total_profit += data[t] - bought_price
            print("Sell: " + formatPrice(data[t]) + " | Profit: " + formatPrice(data[t] - bought_price))
        done = True if t == l - 1 else False
        agent.memory.append((state, action, reward, next_state, done))
        state = next_state
        if done:
            print("--------------------------------")
            print("Total Profit: " + formatPrice(total_profit))
            print("--------------------------------")
        if len(agent.memory) > batch_size:
            agent.expReplay(batch_size)
    if e % 10 == 0:
        agent.model.save(str(e))
# Out:
# Enter stock_name: hdfc
# Window size : 10
# Episode count: 2
# Episode 0/2
# Buy: Rs.978.88
# Sell: Rs.972.50 | Profit: -Rs.6.38
# Buy: Rs.996.38
# Sell: Rs.983.88 | Profit: -Rs.12.50
# Buy: Rs.956.38
# Buy: Rs.956.10
# Buy: Rs.978.00
# Sell: Rs.973.28 | Profit: Rs.16.90
# Buy: Rs.972.70
# Sell: Rs.960.53 | Profit: Rs.4.43
# Buy: Rs.978.88
# Sell: Rs.987.58 | Profit: Rs.9.58
# Buy: Rs.1009.38
# Buy: Rs.1002.75
# Buy: Rs.1024.90
# Sell: Rs.1065.53 | Profit: Rs.92.83
# Buy: Rs.1064.22
# Sell: Rs.1048.53 | Profit: Rs.69.65
# Buy: Rs.1053.80
# Buy: Rs.1044.38
# Sell: Rs.1042.65 | Profit: Rs.33.28
# Sell: Rs.1050.65 | Profit: Rs.47.90
# Buy: Rs.1047.85
# Sell: Rs.1068.72 | Profit: Rs.43.82
# Sell: Rs.1055.57 | Profit: -Rs.8.65
# Buy: Rs.1061.18
# Sell: Rs.1061.45 | Profit: Rs.7.65
# Sell: Rs.1060.85 | Profit: Rs.16.47
# Sell: Rs.1064.25 | Profit: Rs.16.40
# Sell: Rs.1055.90 | Profit: -Rs.5.28
# Buy: Rs.1051.50
# Buy: Rs.1058.40
# Buy: Rs.1054.25
# Buy: Rs.1055.95
# Buy: Rs.1050.82
# Sell: Rs.1060.95 | Profit: Rs.9.45
# Sell: Rs.1060.10 | Profit: Rs.1.70
# Sell: Rs.1066.15 | Profit: Rs.11.90
# Sell: Rs.1065.12 | Profit: Rs.9.18
# Buy: Rs.1067.93
# Sell: Rs.1051.12 | Profit: Rs.0.30
# Sell: Rs.1048.00 | Profit: -Rs.19.93
# Buy: Rs.1028.80
# Buy: Rs.1017.35
# Buy: Rs.1057.03
# Buy: Rs.1061.32
# Buy: Rs.1058.62
# Sell: Rs.1061.32 | Profit: Rs.32.52
# Sell: Rs.1044.95 | Profit: Rs.27.60
# Buy: Rs.1057.95
# Sell: Rs.1045.72 | Profit: -Rs.11.30
# Sell: Rs.1055.32 | Profit: -Rs.6.00
# Sell: Rs.1046.12 | Profit: -Rs.12.50
# Buy: Rs.1038.78
# Buy: Rs.1041.68
# Sell: Rs.1053.55 | Profit: -Rs.4.40
# Sell: Rs.1052.12 | Profit: Rs.13.35
# Sell: Rs.1063.25 | Profit: Rs.21.57
# Buy: Rs.1064.22
# Sell: Rs.1085.50 | Profit: Rs.21.28
# Buy: Rs.1133.88
# Sell: Rs.1138.07 | Profit: Rs.4.20
# Buy: Rs.1151.40
# Sell: Rs.1155.90 | Profit: Rs.4.50
# Buy: Rs.1147.43
# Buy: Rs.1146.38
# Sell: Rs.1141.97 | Profit: -Rs.5.45
# Buy: Rs.1152.80
# Buy: Rs.1144.70
# Buy: Rs.1143.62
# Buy: Rs.1128.75
# Sell: Rs.1132.62 | Profit: -Rs.13.75
# Sell: Rs.1144.40 | Profit: -Rs.8.40
# Sell: Rs.1152.53 | Profit: Rs.7.83
# Sell: Rs.1146.82 | Profit: Rs.3.20
# Sell: Rs.1134.35 | Profit: Rs.5.60
# Buy: Rs.1164.22
# Buy: Rs.1161.18
# Sell: Rs.1153.62 | Profit: -Rs.10.60
# Buy: Rs.1145.45
# Buy: Rs.1216.18
# Sell: Rs.1201.85 | Profit: Rs.40.67
# Sell: Rs.1211.68 | Profit: Rs.66.23
# Sell: Rs.1220.10 | Profit: Rs.3.92
# Buy: Rs.1224.20
# Buy: Rs.1222.35
# Sell: Rs.1217.55 | Profit: -Rs.6.65
# Sell: Rs.1211.00 | Profit: -Rs.11.35
# Buy: Rs.1208.62
# Sell: Rs.1214.18 | Profit: Rs.5.55
# Buy: Rs.1231.15
# Sell: Rs.1221.88 | Profit: -Rs.9.28
# Buy: Rs.1241.90
# Sell: Rs.1204.80 | Profit: -Rs.37.10
# Buy: Rs.1197.38
# Sell: Rs.1195.60 | Profit: -Rs.1.78
# Buy: Rs.1148.62
# Sell: Rs.1140.45 | Profit: -Rs.8.18
# Buy: Rs.1141.00
# Sell: Rs.1110.18 | Profit: -Rs.30.82
# Buy: Rs.1113.85
# Sell: Rs.1112.93 | Profit: -Rs.0.92
# Buy: Rs.1123.88
# Sell: Rs.1124.80 | Profit: Rs.0.93
# Buy: Rs.1199.60
# Buy: Rs.1257.25
# Sell: Rs.1253.80 | Profit: Rs.54.20
# Sell: Rs.1239.70 | Profit: -Rs.17.55
# Buy: Rs.1242.50
# Buy: Rs.1244.20
# Sell: Rs.1227.45 | Profit: -Rs.15.05
# Sell: Rs.1223.55 | Profit: -Rs.20.65
# Buy: Rs.1200.55
# Buy: Rs.1223.05
# Sell: Rs.1221.10 | Profit: Rs.20.55
# Buy: Rs.1229.00
# Buy: Rs.1239.30
# Sell: Rs.1230.35 | Profit: Rs.7.30
# Sell: Rs.1240.05 | Profit: Rs.11.05
# Sell: Rs.1236.85 | Profit: -Rs.2.45
# Buy: Rs.1273.35
# Sell: Rs.1264.75 | Profit: -Rs.8.60
# Buy: Rs.1251.65
# Sell: Rs.1249.50 | Profit: -Rs.2.15
# Buy: Rs.1263.85
# Sell: Rs.1257.35 | Profit: -Rs.6.50
# Buy: Rs.1271.10
# Sell: Rs.1292.35 | Profit: Rs.21.25
# Buy: Rs.1240.95
# Sell: Rs.1260.60 | Profit: Rs.19.65
# Buy: Rs.1223.20
# Sell: Rs.1235.85 | Profit: Rs.12.65
# Buy: Rs.1192.80
# Sell: Rs.1229.80 | Profit: Rs.37.00
# Buy: Rs.1249.00
# Buy: Rs.1241.40
# Buy: Rs.1219.35
# Buy: Rs.1217.15
# Buy: Rs.1213.25
# Sell: Rs.1227.20 | Profit: -Rs.21.80
# Sell: Rs.1217.10 | Profit: -Rs.24.30
# Sell: Rs.1209.95 | Profit: -Rs.9.40
# Sell: Rs.1200.30 | Profit: -Rs.16.85
# Sell: Rs.1199.25 | Profit: -Rs.14.00
# Buy: Rs.1199.45
# Sell: Rs.1177.65 | Profit: -Rs.21.80
# Buy: Rs.895.55
# Buy: Rs.771.55
# Sell: Rs.901.10 | Profit: Rs.5.55
# Buy: Rs.831.65
# Buy: Rs.861.90
# Buy: Rs.829.65
# Buy: Rs.813.85
# Buy: Rs.896.10
# Sell: Rs.888.90 | Profit: Rs.117.35
# Sell: Rs.925.05 | Profit: Rs.93.40
# Buy: Rs.895.35
# Sell: Rs.863.30 | Profit: Rs.1.40
# Sell: Rs.879.75 | Profit: Rs.50.10
# Sell: Rs.910.30 | Profit: Rs.96.45
# Sell: Rs.944.85 | Profit: Rs.48.75
# Sell: Rs.921.65 | Profit: Rs.26.30
# Buy: Rs.923.00
# Sell: Rs.911.45 | Profit: -Rs.11.55
# Buy: Rs.929.05
# Buy: Rs.915.80
# Buy: Rs.901.55
# Sell: Rs.927.65 | Profit: -Rs.1.40
# Sell: Rs.893.70 | Profit: -Rs.22.10
# Sell: Rs.888.15 | Profit: -Rs.13.40
# Buy: Rs.1080.25
# Buy: Rs.1058.85
# Buy: Rs.1053.15
# Buy: Rs.1062.55
# Sell: Rs.1098.45 | Profit: Rs.18.20
# Sell: Rs.1133.05 | Profit: Rs.74.20
# Sell: Rs.1138.55 | Profit: Rs.85.40
# Sell: Rs.1126.35 | Profit: Rs.63.80
# Buy: Rs.1130.40
# Sell: Rs.1119.10 | Profit: -Rs.11.30
# Buy: Rs.1117.05
# Sell: Rs.1119.70 | Profit: Rs.2.65
# Buy: Rs.1118.45
# Buy: Rs.1112.10
# Buy: Rs.1114.50
# Buy: Rs.1115.85
# Buy: Rs.1127.30
# Buy: Rs.1134.15
# Buy: Rs.1130.90
# Buy: Rs.1119.30
# Buy: Rs.1110.50
# Buy: Rs.1112.45
# Buy: Rs.1096.50
# Sell: Rs.1090.55 | Profit: -Rs.27.90
# Sell: Rs.1078.65 | Profit: -Rs.33.45
# Sell: Rs.1057.95 | Profit: -Rs.56.55
# Sell: Rs.1070.50 | Profit: -Rs.45.35
# Sell: Rs.1093.65 | Profit: -Rs.33.65
# Sell: Rs.1083.60 | Profit: -Rs.50.55
# Sell: Rs.1057.30 | Profit: -Rs.73.60
# Sell: Rs.1049.30 | Profit: -Rs.70.00
# Buy: Rs.1035.40
# Sell: Rs.1047.25 | Profit: -Rs.63.25
# Sell: Rs.1030.40 | Profit: -Rs.82.05
# Sell: Rs.1044.00 | Profit: -Rs.52.50
# Sell: Rs.1054.20 | Profit: Rs.18.80
# Buy: Rs.1114.35
# Buy: Rs.1144.10
# Buy: Rs.1162.25
# Sell: Rs.1203.55 | Profit: Rs.89.20
# Sell: Rs.1223.95 | Profit: Rs.79.85
# Sell: Rs.1246.70 | Profit: Rs.84.45
# Buy: Rs.1393.65
# Buy: Rs.1389.95
# Buy: Rs.1371.70
# Buy: Rs.1358.80
# Buy: Rs.1369.70
# Buy: Rs.1408.45
# Buy: Rs.1408.70
# Sell: Rs.1374.35 | Profit: -Rs.19.30
# Sell: Rs.1403.65 | Profit: Rs.13.70
# Sell: Rs.1394.60 | Profit: Rs.22.90
# Sell: Rs.1438.20 | Profit: Rs.79.40
# Sell: Rs.1402.80 | Profit: Rs.33.10
# Sell: Rs.1426.65 | Profit: Rs.18.20
# Sell: Rs.1440.85 | Profit: Rs.32.15
# Buy: Rs.1425.05
# Sell: Rs.1416.00 | Profit: -Rs.9.05
# Buy: Rs.1579.10
# Buy: Rs.1597.60
# Buy: Rs.1605.25
# Buy: Rs.1611.85
# Buy: Rs.1581.75
# Buy: Rs.1554.30
# Buy: Rs.1539.10
# Buy: Rs.1548.00
# Buy: Rs.1529.15
# Sell: Rs.1534.40 | Profit: -Rs.44.70
# Buy: Rs.1568.20
# Buy: Rs.1586.85
# Buy: Rs.1552.05
# Buy: Rs.1530.00
# Buy: Rs.1519.50
# Buy: Rs.1562.50
# Buy: Rs.1555.75
# Buy: Rs.1495.35
# Buy: Rs.1491.00
# Sell: Rs.1500.15 | Profit: -Rs.97.45
# Buy: Rs.1478.80
# Buy: Rs.1463.35
# Buy: Rs.1491.30
# Buy: Rs.1553.70
# Buy: Rs.1493.65
# Buy: Rs.1486.75
# Sell: Rs.1449.60 | Profit: -Rs.155.65
# Buy: Rs.1440.25
# Buy: Rs.1447.20
# Sell: Rs.1400.35 | Profit: -Rs.211.50
# Buy: Rs.1430.10
# Sell: Rs.1428.65 | Profit: -Rs.153.10
# Buy: Rs.1412.40
# Buy: Rs.1391.40
# Buy: Rs.1422.50
# Buy: Rs.1414.15
# Buy: Rs.1404.80
# Buy: Rs.1472.50
# Buy: Rs.1412.30
# Buy: Rs.1414.45
# Buy: Rs.1388.35
# Buy: Rs.1402.60
# Buy: Rs.1419.85
# Buy: Rs.1399.50
# Buy: Rs.1440.25
# Buy: Rs.1476.70
# Buy: Rs.1497.30
# Buy: Rs.1509.95
# Buy: Rs.1478.95
# Buy: Rs.1477.05
# Buy: Rs.1482.65
# Buy: Rs.1503.45
# Buy: Rs.1515.85
# Buy: Rs.1511.70
# Buy: Rs.1504.00
# Buy: Rs.1520.55
# Buy: Rs.1500.95
# Buy: Rs.1499.85
# Sell: Rs.1486.35 | Profit: -Rs.67.95
# Buy: Rs.1466.10
# Buy: Rs.1483.80
# Sell: Rs.1485.50 | Profit: -Rs.53.60
# Buy: Rs.1508.35
# Buy: Rs.1502.05
# Buy: Rs.1497.90
# Sell: Rs.1534.70 | Profit: -Rs.13.30
# Sell: Rs.1520.45 | Profit: -Rs.8.70
# Buy: Rs.1502.00
# Buy: Rs.1487.00
# Buy: Rs.1443.15
# Buy: Rs.1442.75
# Buy: Rs.1434.55
# Buy: Rs.1676.30
# Sell: Rs.1581.45 | Profit: Rs.13.25
# Sell: Rs.1438.90 | Profit: -Rs.147.95
# Sell: Rs.1486.65 | Profit: -Rs.65.40
# Sell: Rs.1497.00 | Profit: -Rs.33.00
# Sell: Rs.1456.10 | Profit: -Rs.63.40
# Sell: Rs.1426.25 | Profit: -Rs.136.25
# Buy: Rs.1366.50
# Sell: Rs.1324.80 | Profit: -Rs.230.95
# Sell: Rs.1327.80 | Profit: -Rs.167.55
# Sell: Rs.1371.15 | Profit: -Rs.119.85
# Buy: Rs.1442.65
# Buy: Rs.1430.90
# Buy: Rs.1342.20
# Buy: Rs.1354.30
# Sell: Rs.1377.70 | Profit: -Rs.101.10
# Sell: Rs.1312.00 | Profit: -Rs.151.35
# Sell: Rs.1307.45 | Profit: -Rs.183.85
# Sell: Rs.1289.75 | Profit: -Rs.263.95
# Sell: Rs.1322.15 | Profit: -Rs.171.50
# Buy: Rs.1371.25
# Sell: Rs.1360.75 | Profit: -Rs.126.00
# Sell: Rs.1446.15 | Profit: Rs.5.90
# Sell: Rs.1465.80 | Profit: Rs.18.60
# Sell: Rs.1472.85 | Profit: Rs.42.75
# Sell: Rs.1464.85 | Profit: Rs.52.45
# Sell: Rs.1465.10 | Profit: Rs.73.70
# Sell: Rs.1439.40 | Profit: Rs.16.90
# Sell: Rs.1486.10 | Profit: Rs.71.95
# Sell: Rs.1472.15 | Profit: Rs.67.35
# Sell: Rs.1485.50 | Profit: Rs.13.00
# Sell: Rs.1495.05 | Profit: Rs.82.75
# Sell: Rs.1489.35 | Profit: Rs.74.90
# Sell: Rs.1482.30 | Profit: Rs.93.95
# Sell: Rs.1497.60 | Profit: Rs.95.00
# Sell: Rs.1498.60 | Profit: Rs.78.75
# Sell: Rs.1493.55 | Profit: Rs.94.05
# Sell: Rs.1513.10 | Profit: Rs.72.85
# Sell: Rs.1528.65 | Profit: Rs.51.95
# Sell: Rs.1520.70 | Profit: Rs.23.40
# Sell: Rs.1492.75 | Profit: -Rs.17.20
# Sell: Rs.1502.60 | Profit: Rs.23.65
# Sell: Rs.1520.70 | Profit: Rs.43.65
# Sell: Rs.1518.35 | Profit: Rs.35.70
# Sell: Rs.1486.00 | Profit: -Rs.17.45
# Sell: Rs.1446.15 | Profit: -Rs.69.70
# Sell: Rs.1426.65 | Profit: -Rs.85.05
# Sell: Rs.1413.85 | Profit: -Rs.90.15
# Sell: Rs.1389.55 | Profit: -Rs.131.00
# Sell: Rs.1382.35 | Profit: -Rs.118.60
# Sell: Rs.1421.35 | Profit: -Rs.78.50
# Sell: Rs.1413.20 | Profit: -Rs.52.90
# Sell: Rs.1453.00 | Profit: -Rs.30.80
# Sell: Rs.1437.00 | Profit: -Rs.71.35
# Sell: Rs.1430.80 | Profit: -Rs.71.25
# Sell: Rs.1415.00 | Profit: -Rs.82.90
# Sell: Rs.1400.65 | Profit: -Rs.101.35
# Sell: Rs.1409.80 | Profit: -Rs.77.20
# Sell: Rs.1393.60 | Profit: -Rs.49.55
# Sell: Rs.1439.00 | Profit: -Rs.3.75
# Sell: Rs.1446.55 | Profit: Rs.12.00
# Sell: Rs.1443.85 | Profit: -Rs.232.45
# Sell: Rs.1458.65 | Profit: Rs.92.15
# Sell: Rs.1448.80 | Profit: Rs.6.15
# Sell: Rs.1438.60 | Profit: Rs.7.70
# Sell: Rs.1461.05 | Profit: Rs.118.85
# Sell: Rs.1450.90 | Profit: Rs.96.60
# Sell: Rs.1454.40 | Profit: Rs.83.15
# --------------------------------
# Total Profit: -Rs.1686.07
# --------------------------------
# INFO:tensorflow:Assets written to: 0\assets
# Episode 1/2
# Buy: Rs.1062.55
# Buy: Rs.1098.45
# Sell: Rs.1133.05 | Profit: Rs.70.50
# Sell: Rs.1138.55 | Profit: Rs.40.10
# Buy: Rs.1611.85
# Buy: Rs.1581.75
# Sell: Rs.1572.35 | Profit: -Rs.39.50
# Sell: Rs.1581.95 | Profit: Rs.0.20
# Buy: Rs.1491.00
# Sell: Rs.1497.50 | Profit: Rs.6.50
# Buy: Rs.1421.75
# Sell: Rs.1367.05 | Profit: -Rs.54.70
# Buy: Rs.1507.65
# Buy: Rs.1494.95
# Buy: Rs.1501.40
# Buy: Rs.1526.20
# Buy: Rs.1530.60
# Buy: Rs.1514.65
# Buy: Rs.1513.00
# Buy: Rs.1514.75
# Buy: Rs.1524.60
# Buy: Rs.1558.85
# Buy: Rs.1557.40
# Buy: Rs.1554.80
# Buy: Rs.1548.45
# Buy: Rs.1568.25
# Buy: Rs.1581.40
# Buy: Rs.1579.10
# Sell: Rs.1589.00 | Profit: Rs.81.35
# Sell: Rs.1576.05 | Profit: Rs.81.10
# Sell: Rs.1565.70 | Profit: Rs.64.30
# Sell: Rs.1569.25 | Profit: Rs.43.05
# Sell: Rs.1576.40 | Profit: Rs.45.80
# Sell: Rs.1568.60 | Profit: Rs.53.95
# Sell: Rs.1555.55 | Profit: Rs.42.55
# Sell: Rs.1548.55 | Profit: Rs.33.80
# Sell: Rs.1546.80 | Profit: Rs.22.20
# Sell: Rs.1559.95 | Profit: Rs.1.10
# Sell: Rs.1582.15 | Profit: Rs.24.75
# Sell: Rs.1559.85 | Profit: Rs.5.05
# Sell: Rs.1551.95 | Profit: Rs.3.50
# Sell: Rs.1533.70 | Profit: -Rs.34.55
# Sell: Rs.1570.00 | Profit: -Rs.11.40
# Sell: Rs.1601.55 | Profit: Rs.22.45
# Buy: Rs.1466.30
# Buy: Rs.1485.70
# Buy: Rs.1485.15
# Buy: Rs.1502.15
# Sell: Rs.1509.90 | Profit: Rs.43.60
# Sell: Rs.1511.70 | Profit: Rs.26.00
# Sell: Rs.1493.05 | Profit: Rs.7.90
# Sell: Rs.1470.35 | Profit: -Rs.31.80
# --------------------------------
# Total Profit: Rs.547.80
# --------------------------------
# Episode 2/2
# Buy: Rs.984.40
# Buy: Rs.980.60
# Buy: Rs.963.15
# Sell: Rs.956.38 | Profit: -Rs.28.03
# Sell: Rs.955.88 | Profit: -Rs.24.72
# Sell: Rs.956.10 | Profit: -Rs.7.05
# Buy: Rs.1074.05
# Buy: Rs.1064.25
# Buy: Rs.1055.90
# Sell: Rs.1058.72 | Profit: -Rs.15.33
# Sell: Rs.1060.32 | Profit: -Rs.3.93
# Sell: Rs.1051.50 | Profit: -Rs.4.40
# Buy: Rs.1046.12
# Buy: Rs.1038.78
# Buy: Rs.1041.68
# Sell: Rs.1053.55 | Profit: Rs.7.43
# Sell: Rs.1052.12 | Profit: Rs.13.35
# Sell: Rs.1063.25 | Profit: Rs.21.57
# Buy: Rs.1223.82
# Buy: Rs.1220.10
# Buy: Rs.1224.20
# Sell: Rs.1213.53 | Profit: -Rs.10.30
# Sell: Rs.1222.35 | Profit: Rs.2.25
# Sell: Rs.1217.55 | Profit: -Rs.6.65
# Buy: Rs.1089.62
# Buy: Rs.1094.55
# Buy: Rs.1092.00
# Sell: Rs.1116.57 | Profit: Rs.26.95
# Sell: Rs.1141.00 | Profit: Rs.46.45
# Sell: Rs.1110.18 | Profit: Rs.18.18
# Buy: Rs.1242.95
# Buy: Rs.1249.50
# Sell: Rs.1248.75 | Profit: Rs.5.80
# Sell: Rs.1263.60 | Profit: Rs.14.10
# Buy: Rs.1268.40
# Sell: Rs.1240.95 | Profit: -Rs.27.45
# Buy: Rs.1179.60
# Buy: Rs.1181.80
# Sell: Rs.1148.85 | Profit: -Rs.30.75
# Sell: Rs.1151.35 | Profit: -Rs.30.45
# Buy: Rs.882.85
# Sell: Rs.771.55 | Profit: -Rs.111.30
# Buy: Rs.893.70
# Buy: Rs.888.15
# Buy: Rs.836.65
# Sell: Rs.830.65 | Profit: -Rs.63.05
# Sell: Rs.857.10 | Profit: -Rs.31.05
# Sell: Rs.859.55 | Profit: Rs.22.90
# Buy: Rs.1027.55
# Buy: Rs.1040.70
# Sell: Rs.1043.85 | Profit: Rs.16.30
# Sell: Rs.1050.65 | Profit: Rs.9.95
# Buy: Rs.1203.55
# Buy: Rs.1223.95
# Sell: Rs.1246.70 | Profit: Rs.43.15
# Sell: Rs.1233.30 | Profit: Rs.9.35
# Buy: Rs.1503.85
# Buy: Rs.1492.00
# Sell: Rs.1474.80 | Profit: -Rs.29.05
# Sell: Rs.1443.55 | Profit: -Rs.48.45
# Buy: Rs.1500.15
# Buy: Rs.1478.80
# Sell: Rs.1463.35 | Profit: -Rs.36.80
# Sell: Rs.1491.30 | Profit: Rs.12.50
# Buy: Rs.1504.00
# Buy: Rs.1520.55
# Sell: Rs.1500.95 | Profit: -Rs.3.05
# Sell: Rs.1499.85 | Profit: -Rs.20.70
# Buy: Rs.1434.55
# Buy: Rs.1439.75
# Buy: Rs.1417.30
# Sell: Rs.1418.25 | Profit: -Rs.16.30
# Sell: Rs.1426.45 | Profit: -Rs.13.30
# Sell: Rs.1422.65 | Profit: Rs.5.35
# Buy: Rs.1601.55
# Buy: Rs.1625.10
# Buy: Rs.1615.05
# Sell: Rs.1593.85 | Profit: -Rs.7.70
# Sell: Rs.1594.95 | Profit: -Rs.30.15
# Sell: Rs.1582.70 | Profit: -Rs.32.35
# Buy: Rs.1530.80
# Buy: Rs.1539.40
# Buy: Rs.1515.35
# Buy: Rs.1515.55
# Sell: Rs.1518.05 | Profit: -Rs.12.75
# Sell: Rs.1525.95 | Profit: -Rs.13.45
# Sell: Rs.1489.90 | Profit: -Rs.25.45
# Sell: Rs.1501.25 | Profit: -Rs.14.30
# Buy: Rs.1539.75
# Buy: Rs.1550.55
# Buy: Rs.1559.15
# Buy: Rs.1565.90
# Buy: Rs.1556.65
# Sell: Rs.1528.00 | Profit: -Rs.11.75
# Sell: Rs.1545.15 | Profit: -Rs.5.40
# Sell: Rs.1521.50 | Profit: -Rs.37.65
# Sell: Rs.1529.25 | Profit: -Rs.36.65
# Sell: Rs.1518.45 | Profit: -Rs.38.20
# Buy: Rs.1456.10
# Buy: Rs.1426.25
# Buy: Rs.1374.25
# Buy: Rs.1371.00
# Buy: Rs.1366.50
# Sell: Rs.1324.80 | Profit: -Rs.131.30
# Sell: Rs.1327.80 | Profit: -Rs.98.45
# Sell: Rs.1371.15 | Profit: -Rs.3.10
# Sell: Rs.1392.70 | Profit: Rs.21.70
# Sell: Rs.1396.80 | Profit: Rs.30.30
# Buy: Rs.1434.20
# Buy: Rs.1446.15
# Sell: Rs.1430.25 | Profit: -Rs.3.95
# Sell: Rs.1433.60 | Profit: -Rs.12.55
# Buy: Rs.1426.65
# Buy: Rs.1413.85
# Buy: Rs.1389.55
# Sell: Rs.1382.35 | Profit: -Rs.44.30
# Sell: Rs.1421.35 | Profit: Rs.7.50
# Sell: Rs.1413.20 | Profit: Rs.23.65
# --------------------------------
# Total Profit: -Rs.762.83
# --------------------------------
